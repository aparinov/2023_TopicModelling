# %% [markdown]
# # Цель работы:
#  Исследовать сходство и различия в толковании понятий "machine learning" и "data science" через анализ публикаций в Arxive с использованием метода обобщения в таксономиях

# %% [markdown]
# # Шаг 1
# Выделить подмножества публикаций в Arxive, ML и DS, отвечающие соответствующим запросам

# %%
import pandas as pd
import numpy as np

df = pd.read_json('arxiv-metadata-oai-snapshot.json', lines=True)

# %% [markdown]
# Filter ML and AI from past 10 years

# %%
df_LG = df[df['categories'].str.contains('cs.LG')]

# %%
df_AI = df[df['categories'].str.contains('cs.AI')]

# %%
df_ML = df[df['categories'].str.contains('stat.ML')]

# %%
df_LG = df_LG[df_LG['update_date'] > '2022']

# %%
df_AI = df_AI[df_AI['update_date'] > '2022']

# %%
df_ML = df_ML[df_ML['update_date'] > '2022']

# %%
print(f'ML articles: {len(df_LG)}')
print(f'AI articles: {len(df_AI)}')
print(f'ML (statistics) articles: {len(df_ML)}')
# Out:
# ML articles: 42929
# AI articles: 20841
# ML (statistics) articles: 9336

# %%
abstracts_LG = []
for a in df_LG['abstract']:
    abstracts_LG.append(a)

# %%
abstracts_AI = []

for a in df_AI['abstract']:
    abstracts_AI.append(a)

# %%
abstracts_ML = []

for a in df_ML['abstract']:
    abstracts_ML.append(a)

# %% [markdown]
# ## Шаг 2
# Выделить разумные нечеткие кластеры понятий таксономии согласно ML и согласно DS

# %%
import re

import numpy as np

from east.asts import base


def clear_text(text, lowerize=True):

    pat = re.compile(r'[^A-Za-z0-9 \-\n\r.,;!?А-Яа-я]+')
    cleared_text = re.sub(pat, ' ', text)

    if lowerize:
        cleared_text = cleared_text.lower()

    tokens = cleared_text.split()
    return tokens


def make_substrings(tokens, k=4):

    for i in range(max(len(tokens) - k + 1, 1)):
        yield ' '.join(tokens[i:i + k])


def get_corelevance_matrix(texts):

    matrix = np.empty((0, len(texts)), float)
    prepared_text_tokens = [clear_text(t) for t in texts]
    prepared_texts = [' '.join(t) for t in prepared_text_tokens]

    for text_tokens in prepared_text_tokens:
        ast = base.AST.get_ast(list(make_substrings(text_tokens)))
        row = np.array([ast.score(t) for t in prepared_texts])
        matrix = np.append(matrix, [row], axis=0)

    return matrix


def get_relevance_matrix(texts, strings):

    matrix = np.empty((0, len(strings)), float)
    prepared_text_tokens = [clear_text(t) for t in texts]

    prepared_string_tokens = [clear_text(s) for s in strings]
    prepared_strings = [' '.join(t) for t in prepared_string_tokens]
    
    #for print
    print(f'total len: {len(prepared_text_tokens)}')
    c = 0

    for text_tokens in prepared_text_tokens:
        ast = base.AST.get_ast(list(make_substrings(text_tokens)))
        row = np.array([ast.score(s) for s in prepared_strings])
        matrix = np.append(matrix, [row], axis=0)
        
        c += 1
        print(f'processed: {c}')
    return matrix


def save_matrix(matrix, filename="filename"):
    np.savetxt(filename, matrix)

# %% [markdown]
# Get strings of terms

# %%
with open("taxonomies/taxonomy_leaves.txt") as f:
    strings = [l.strip() for l in f.readlines()]

# %%
# Relevance between the texts and strings:

relevance_matrix_LG = get_relevance_matrix(abstracts_LG, strings)
print("Relevance mairix LG:")
print(relevance_matrix_LG)

save_matrix(relevance_matrix_LG, "matrixes/relevmtx_LG")

# %%
# Relevance between the texts and strings:

relevance_matrix_AI = get_relevance_matrix(abstracts_AI, strings)
print("Relevance mairix AI:")
print(relevance_matrix_AI)

save_matrix(relevance_matrix_AI, "matrixes/relevmtx_AI")

# %%
# Relevance between the texts and strings:

relevance_matrix_ML = get_relevance_matrix(abstracts_ML, strings)
print("Relevance mairix ML:")
print(relevance_matrix_ML)

save_matrix(relevance_matrix_ML, "matrixes/relevmtx_ML")

# %% [markdown]
# Obtain fuzzy clusters

# %%
import numpy as np
from pyfaddis.lapin import lapin
from pyfaddis.faddis import faddis

from operator import itemgetter

# %%
relevance_matrix_LG = np.loadtxt("matrixes/relevmtx_LG")
print(relevance_matrix_LG.shape)
tc = relevance_matrix_LG.T.dot(relevance_matrix_LG)
print(tc.shape)

tc_transformed = lapin(tc)
B, member, contrib, intensity, lat, tt = faddis(tc_transformed)
np.savetxt("clusters/clusters_LG.dat", member)
np.save("clusters/LG_contrib", contrib)
np.save("clusters/LG_intensity", intensity)
np.save("clusters/LG_lat", lat)
np.save("clusters/LG_tt", tt)

# %%
relevance_matrix_AI = np.loadtxt("matrixes/relevmtx_AI")
print(relevance_matrix_AI.shape)
tc = relevance_matrix_AI.T.dot(relevance_matrix_AI)
print(tc.shape)

tc_transformed = lapin(tc)
B, member, contrib, intensity, lat, tt = faddis(tc_transformed)
np.savetxt("clusters/clusters_AI.dat", member)
np.save("clusters/AI_contrib", contrib)
np.save("clusters/AI_intensity", intensity)
np.save("clusters/AI_lat", lat)
np.save("clusters/AI_tt", tt)
# Out:
# (20841, 379)
# (379, 379)
# Cluster contribution is too small

# %%
relevance_matrix_ML = np.loadtxt("matrixes/relevmtx_ML")
print(relevance_matrix_ML.shape)
tc = relevance_matrix_ML.T.dot(relevance_matrix_ML)
print(tc.shape)

tc_transformed = lapin(tc)
B, member, contrib, intensity, lat, tt = faddis(tc_transformed)
np.savetxt("clusters/clusters_ML.dat", member)
np.save("clusters/ML_contrib", contrib)
np.save("clusters/ML_intensity", intensity)
np.save("clusters/ML_lat", lat)
np.save("clusters/ML_tt", tt)
# Out:
# (9336, 379)
# (379, 379)
# Cluster contribution is too small

# %% [markdown]
# # Analysis

# %%
print(f'ML articles: {len(df_LG)}')
print(f'AI articles: {len(df_AI)}')
print(f'ML (statistics) articles: {len(df_ML)}')
# Out:
# ML articles: 42929
# AI articles: 20841
# ML (statistics) articles: 9336

# %%
member_LG = np.loadtxt('clusters/clusters_LG.dat')
member_AI = np.loadtxt('clusters/clusters_AI.dat')
member_ML = np.loadtxt('clusters/clusters_ML.dat')

# %%
terms_LG = []
for i, el in enumerate(strings):
    terms_LG.append((el, member_LG[i, 0], member_LG[i, 1], member_LG[i, 2], member_LG[i, 3], member_LG[i, 4]))

terms_AI = []
for i, el in enumerate(strings):
    terms_AI.append((el, member_AI[i, 0], member_AI[i, 1], member_AI[i, 2], member_AI[i, 3], member_AI[i, 4]))
    
terms_ML = []
for i, el in enumerate(strings):
    terms_ML.append((el, member_ML[i, 0], member_ML[i, 1], member_ML[i, 2]))

# %% [markdown]
# #### Machine Leaning (Computer Science)

# %%
contrib_LG = np.load('clusters/LG_contrib.npy')
print(f'Cluster contributions: {contrib_LG}')
# Out:
# Cluster contributions: [0.01593554 0.01557557 0.00655408 0.00712074 0.00241163]

# %%
print('Machine Learning, Cluster 1:')
terms_LG.sort(reverse=True, key=lambda x: x[1])
for el in terms_LG:
    if el[1] == 0:
        break
    print(f'{el[0]}:\t\t{el[1]}')
# Out:
# Machine Learning, Cluster 1:
# data provenance:		0.4337646436749266
# 2d pca:		0.4200553802871822
# bayesian network models:		0.37343141255300594
# adversarial learning:		0.33608056630589883
# cluster analysis:		0.29552641681032543
# markov networks:		0.2428307758986762
# distributed database recovery:		0.2425845115367029
# data exchange:		0.1974674127407011
# data cleaning:		0.19617240053455479
# information extraction:		0.1337805882877761
# sequential decision making:		0.13071013153836322
# anomaly detection:		0.11189830511379048
# markov decision processes:		0.10469428507884355
# recommender systems:		0.10017294688175708
# inverse reinforcement learning:		0.08648519759893851
# data locking:		0.08620640658775858
# learning to rank:		0.08417138190948344
# multi-agent reinforcement learning:		0.06871282152177126
# apprenticeship learning:		0.059628387249230516
# support vector machines:		0.038684693115777054
# boosting:		0.00789701305904788
# gaussian processes:		0.006527853448585735
# fuzzy representation:		3.200534048444169e-10
# inconsistent:		2.59139468219778e-10
# content analysis and feature selection:		1.8141772844318826e-10
# video segmentation:		1.7192382402969438e-10
# data integration:		1.3574018992987008e-10
# query learning:		1.321579692653101e-10
# online learning settings:		1.2686183852659742e-10
# knowledge discovery:		1.0896781870808551e-10
# data streams:		1.0807340994259629e-10
# semi-structured data:		1.0646443649356015e-10
# relational database model:		9.823933281078276e-11
# data modeling:		9.563697499883632e-11
# appearance and texture representations:		8.404739037524198e-11
# queueing theory:		7.91983040312018e-11
# probabilistic algorithms:		7.919390226903923e-11
# image search:		7.684312390628138e-11
# process mining:		7.663416689042515e-11
# document topic models:		7.295629926887134e-11
# multidimensional range search:		7.229553472153563e-11
# active learning:		6.894712294128965e-11
# supervised learning by classification:		6.663563536521183e-11
# database query languages:		6.108961944190014e-11
# novelty in information retrieval:		5.866537687171979e-11
# entity resolution:		5.73866765882347e-11
# logic programming and answer set programming:		5.004847431482743e-11
# search results deduplication:		4.697119416358291e-11
# factor graphs:		4.4610906906861e-11
# geographic visualization:		4.431561546597677e-11
# speech recognition:		4.3593176643697515e-11
# web log analysis:		4.26371081400812e-11
# object detection:		4.248051029913309e-11
# query optimization:		3.847516351059231e-11
# structured query language:		3.376954251632872e-11
# supervised learning by regression:		3.3668631435172447e-11
# music retrieval:		3.34973859800928e-11
# decision diagrams:		3.2922024135015554e-11
# parallel computation:		3.2677403921248765e-11
# massive data clustering:		3.15354074630758e-11
# mixture models:		2.919644893903573e-11
# kernel independent components:		2.912214612902908e-11
# nonparametric statistics:		2.8723833288517723e-11
# frequent graph mining:		2.854227588184362e-11
# unsupervised learning and clustering:		2.819595726010049e-11
# graph based conceptual clustering:		2.641967852879188e-11
# temporal data:		2.4913322327441884e-11
# biclustering:		2.4680112760219566e-11
# stochastic differential equations:		2.4184379976402963e-11
# inductive logic learning:		2.297866610523462e-11
# thesauri:		2.0910898116431953e-11
# logic and databases:		2.0265621243180926e-11
# data encryption:		1.9634093190892323e-11
# survival analysis:		1.9135076509686594e-11
# online analytical processing engines:		1.8987227148737003e-11
# web and social media search:		1.8922019939877683e-11
# transaction logging:		1.8824636796826467e-11
# search interfaces:		1.8205075539927086e-11
# data mining tools:		1.720676060560566e-11
# approximate dynamic programming methods:		1.704959676799338e-11
# query operators:		1.687910586836399e-11
# canonical correlation analysis:		1.6426338541103233e-11
# interestingness:		1.6076733620615256e-11
# task models:		1.5962312234017195e-11
# desktop search:		1.5803828581410156e-11
# reasoning about belief and knowledge:		1.5531020295875055e-11
# triggers and rules:		1.5085050984712322e-11
# multivariate statistics:		1.495156585663673e-11
# knowledge sharing:		1.472074570723575e-11
# bayesian analysis:		1.464144690074584e-11
# document collection models:		1.4610538513648825e-11
# point lookups:		1.4397631301052716e-11
# consensus clustering:		1.4373413572919398e-11
# kernel-based clustering:		1.3778847610092731e-11
# shape inference:		1.3764956919349236e-11
# kernel density estimators:		1.3164764401523205e-11
# mapreduce languages:		1.3142871860857813e-11
# dbms engine architectures:		1.2784869520675641e-11
# semantic inference:		1.2675604301356845e-11
# xquery:		1.2569925440156944e-11
# hierarchical data models:		1.2373252021374019e-11
# generative adversarial networks gan:		1.1846780216435307e-11
# data structures and algorithms for data management:		1.1802061435105616e-11
# visualization toolkits:		1.1673548880598844e-11
# default reasoning and belief revision:		1.0256570583640892e-11
# additive clustering:		9.91144765139421e-12
# expectation maximization:		9.626232326718698e-12
# bootstrapping:		9.51996721501074e-12
# tensor factorization:		8.99904840920426e-12
# learning from critiques:		8.927922565665119e-12
# retrieval effectiveness:		8.772209606109495e-12
# deep web:		8.752814972289144e-12
# dropout:		8.23120011152887e-12
# splitting criteria:		8.186206402380377e-12
# validation of data:		7.741031157133576e-12
# smart home:		7.552161846515064e-12
# dimensionality reduction:		7.396457384722519e-12
# matching:		7.387530474419484e-12
# data warehouses:		7.3397078873147e-12
# item-based:		7.303328435551763e-12
# multilingual and cross-lingual retrieval:		7.078529308981936e-12
# mathematics retrieval:		7.022262027566642e-12
# key-value stores:		6.997032284952907e-12
# semantic networks:		6.565827679614212e-12
# relevance assessment:		6.167194791195539e-12
# policy iteration:		6.159743517559785e-12
# graph drawings:		6.052765627423465e-12
# time series analysis:		5.8270538932612606e-12
# document filtering:		5.826032222360441e-12
# variational methods:		5.728093620952368e-12
# visualization theory concepts and paradigms:		5.672437241183403e-12
# cognitive robotics:		5.6514172368516776e-12
# retrieval efficiency:		5.641817562704242e-12
# causal networks:		5.633633696478364e-12
# combination fusion and federated search:		5.569369190230503e-12
# exploratory data analysis:		5.470532230373965e-12
# non-negative matrix factorization:		5.268316996898811e-12
# record and buffer management:		5.142010580381369e-12
# structured prediction:		5.061361945121657e-12
# regret bounds:		4.936819934767867e-12
# answering queries:		4.8872883790969365e-12
# recurrent neural networks rnn:		4.652102238454445e-12
# sparse tensor:		4.462721610511804e-12
# partially-observable markov decision processes:		4.456552813667655e-12
# hyperbolic trees:		3.934707118344359e-12
# trajectory clustering:		3.798516062220672e-12
# kernel approach:		3.7221806240157485e-12
# elastic maps:		3.7014564553655004e-12
# scalable:		3.700258767530317e-12
# perceptron algorithm:		3.68677691710802e-12
# generalized eigenvalue:		3.4795929737712194e-12
# click through data:		3.3868225505331084e-12
# jackknifing:		3.2663421782256203e-12
# heat maps:		3.1783586221798176e-12
# hadoop:		2.9366061684205434e-12
# random number generation:		2.8882872942817134e-12
# maximum likelihood modeling:		2.7614270023296946e-12
# auto-encoder:		2.6254830442793202e-12
# incomplete data:		2.4455713641803355e-12
# business intelligence:		2.4290486130773822e-12
# distribution functions:		2.115235456266902e-12
# gibbs sampling:		2.1057387810695637e-12
# self organized map:		1.9949092799511655e-12
# reconstruction:		1.9629220509496367e-12
# taxonomy mapping:		1.840291031428734e-12
# parallel implementation:		1.7607137939865105e-12
# query planning:		1.7154074641385434e-12
# nearest-neighbor search:		1.6415176703935908e-12
# object identification:		1.5341933764237595e-12
# quality of the data:		1.5208019393427315e-12
# main memory engines:		1.519987834367438e-12
# similarity measures:		1.5166171446534228e-12
# maximum a posteriori modeling:		1.406561738704422e-12
# loopy belief propagation:		1.283051665241394e-12
# language resources:		1.2756774295092479e-12
# phonology:		1.221980315674517e-12
# spatial and physical reasoning:		1.132792711932971e-12
# data compression:		1.0701339497819204e-12
# machine translation:		7.850987812641676e-13
# learning under covariate shift:		5.75793131076395e-13
# learning from demonstrations:		5.375532391461019e-13
# rule and pattern discovery:		3.053630679433121e-13
# cladograms:		2.742120660732e-13
# feature weight clustering:		2.4877723917448805e-13
# personalization:		1.6963876553676955e-13

# %%
print('Machine Learning, Cluster 2:')
terms_LG.sort(reverse=True, key=lambda x: x[2])
for el in terms_LG:
    if el[2] == 0:
        break
    print(f'{el[0]}:\t\t{el[2]}')
# Out:
# Machine Learning, Cluster 2:
# data provenance:		0.4396953457030884
# 2d pca:		0.4261918057130437
# adversarial learning:		0.33991644481846445
# markov network models:		0.337185005712885
# cluster analysis:		0.29965509845437854
# bayesian networks:		0.2838477447980121
# data cleaning:		0.20021050762244857
# data exchange:		0.19748113508204618
# distributed data locking:		0.18739884707557178
# database recovery:		0.1427764126134109
# information extraction:		0.1355731243340465
# sequential decision making:		0.1273557894597782
# anomaly detection:		0.10996522792090706
# markov decision processes:		0.10240506566044434
# recommender systems:		0.0993942122933422
# inverse reinforcement learning:		0.08781355067614915
# learning to rank:		0.07964307184603972
# multi-agent reinforcement learning:		0.06636223012671934
# apprenticeship learning:		0.06031408968942941
# support vector machines:		0.04020082421555917
# boosting:		0.007277178418447111
# gaussian processes:		0.004412184746553468

# %%
print('Machine Learning, Cluster 3:')
terms_LG.sort(reverse=True, key=lambda x: x[3])
for el in terms_LG:
    if el[3] == 0:
        break
    print(f'{el[0]}:\t\t{el[3]}')
# Out:
# Machine Learning, Cluster 3:
# learning to rank:		0.415242407867412
# sequential decision making:		0.394426726457116
# support vector machines:		0.3606143248419246
# markov decision processes:		0.3142283090006086
# data cleaning:		0.2785466464726828
# information extraction:		0.24724563515801362
# anomaly detection:		0.22278892218598814
# inverse reinforcement learning:		0.22127732072230655
# apprenticeship learning:		0.2127356688332793
# multi-agent reinforcement learning:		0.18151191850018808
# data exchange:		0.16828878348945764
# cluster analysis:		0.15635097039667567
# recommender systems:		0.13433996479355195
# distributed data locking:		0.09872628766826216
# 2d pca:		0.09811096193279259
# data provenance:		0.0966267289547563
# gaussian processes:		0.08875219552958068
# boosting:		0.08825170205309776
# database recovery:		0.07544625232640033
# markov network models:		0.06283010452172838
# bayesian networks:		0.052930468198218075
# adversarial learning:		0.008300701757279474

# %%
print('Machine Learning, Cluster 4:')
terms_LG.sort(reverse=True, key=lambda x: x[4])
for el in terms_LG:
    if el[4] == 0:
        break
    print(f'{el[0]}:\t\t{el[4]}')
# Out:
# Machine Learning, Cluster 4:
# learning to rank:		0.428250270584852
# sequential decision making:		0.40188377577237333
# support vector machines:		0.37609595455774997
# markov decision processes:		0.3202858950697762
# data cleaning:		0.2726319991639786
# information extraction:		0.24559003539328272
# inverse reinforcement learning:		0.2236187067978763
# anomaly detection:		0.2216679317871739
# apprenticeship learning:		0.2170748235851293
# multi-agent reinforcement learning:		0.182571231095051
# data exchange:		0.15565322824366057
# cluster analysis:		0.13328470956239333
# recommender systems:		0.1302826306169525
# distributed database recovery:		0.1081334582627704
# gaussian processes:		0.09153375397976467
# boosting:		0.09099344956053369
# 2d pca:		0.059541528210488706
# data provenance:		0.055173096029132465
# data locking:		0.037500644647982466
# bayesian network models:		0.03283750788195399
# markov networks:		0.020742726760064008

# %%
print('Machine Learning, Cluster 5:')
terms_LG.sort(reverse=True, key=lambda x: x[5])
for el in terms_LG:
    if el[5] == 0:
        break
    print(f'{el[0]}:\t\t{el[5]}')
# Out:
# Machine Learning, Cluster 5:
# query representation:		0.9263917911984688
# fuzzy clustering:		0.22333130825872058
# mixture modeling:		0.19808927760468295
# hierarchical data models:		0.1403275886325566
# inconsistent data:		0.10157868558958608
# document topic models:		0.08242752357094182
# test collections:		0.05483188201885137
# probabilistic retrieval models:		0.05083477963391369
# temporal reasoning:		0.04414367642360795
# vagueness and fuzzy logic:		0.030620996307408
# neuro-fuzzy approach:		0.029732505973361467
# kernel independent components:		0.02704075883930022
# search results deduplication:		0.02613326096397946
# shape representations:		0.025940410527286246
# database query processing and optimization:		0.019880117068685553
# active learning:		0.019522033866878466
# sparse tensor:		0.019032182537057133
# canonical correlation analysis:		0.01846109330491038
# online learning settings:		0.015424708539636922
# object recognition:		0.012936945940312033
# models of learning:		0.01269886074416544
# structured query language:		0.011030898110191928
# factor analysis:		0.010618689072285787
# semantic inference:		0.010509285897655936
# appearance and texture representations:		0.009838115496198419
# supervised dimesionality reduction:		0.00970790734844937
# parallel computation:		0.009241714392839414
# database interoperability:		0.008778676977526009
# inductive inference:		0.00859820543401103
# interest point and salient region detections:		0.008560315665442339
# combination fusion and federated search:		0.00839353545481395
# supervised learning by classification:		0.008367058091951261
# deep belief networks:		0.00816166541234788
# knowledge graph:		0.007569876677245417
# language models:		0.00701742247636703
# model trees:		0.006649650440070791
# queueing theory:		0.006582918765497006
# statistical relational learning:		0.006470782144692557
# maximum likelihood modeling:		0.006400872315020233
# task models:		0.006318127012578111
# tensor factorization:		0.006092238788662492
# traffic analysis:		0.005789185369468142
# database views:		0.005741444920754757
# kernel matrix:		0.005728787978827239
# entity relationship models:		0.005721689572868156
# expectation maximization:		0.005677997548746733
# conceptual design:		0.005607871614581293
# distributed data locking:		0.005522143168269447
# kernel density estimators:		0.005442706463415303
# variational methods:		0.005402741733880891
# physical data models:		0.005203138130506452
# near-duplicate and plagiarism detection:		0.005145785893619049
# formal concept analysis:		0.005128319874627532
# multi-agent reinforcement learning:		0.005118668525888746
# multi-agent reinforcement learning:		0.005118614971523056
# inverse reinforcement learning:		0.005118600076650951
# inverse reinforcement learning:		0.005116618405819374
# item-based:		0.005023526018501161
# distributed database recovery:		0.004936731562203702
# bayesian nonparametric models:		0.004920836052038833
# stochastic differential equations:		0.004759691008991926
# speech:		0.004704442334726712
# visual analytics:		0.004557699732847009
# multidimensional range search:		0.004533685222251152
# wikipedia based semantics:		0.004097077056766646
# elastic maps:		0.004092590940388726
# image segmentation:		0.004083966392420891
# mapreduce:		0.004016252998838648
# policy iteration:		0.004005495394803827
# content analysis and feature selection:		0.004000923720542392
# web and social media search:		0.003908033743035885
# query log analysis:		0.0036957956861881813
# data stream mining:		0.003637589418285312
# spline models:		0.003583274216172731
# fusion of classifiers:		0.0033169631674581598
# statistical graphics:		0.0032582707446077086
# answering queries:		0.0031909009011278767
# data structures and algorithms for data management:		0.003127322428996995
# rule and pattern discovery:		0.0028872275113217215
# chemical and biochemical retrieval:		0.0026956493518925265
# boolean function learning:		0.002489129364984678
# join algorithms:		0.0024004962628304863
# tracking:		0.0022285739682263122
# multiresolution:		0.002130124181112495
# equational models:		0.0020314893681235052
# apprenticeship learning:		0.0018817285179618675
# apprenticeship learning:		0.0018813113256471341
# smart home:		0.0018236130327220618
# metropolis-hastings algorithm:		0.0018086454349747262
# sample complexity and generalization bounds:		0.0018019856644227263
# learning from critiques:		0.0017366173769253817
# critical nodes detection:		0.001698832590009459
# cladograms:		0.0016910218943946478
# visualization theory concepts and paradigms:		0.0016474885821091045
# structured outputs:		0.001628526749184939
# q-learning:		0.0016162721370207385
# exploratory data analysis:		0.001561871013032585
# transfer learning:		0.0015583177268934396
# sentiment analysis:		0.0015460352885907367
# key-phrase indexing:		0.0015449943139050717
# top-k retrieval in databases:		0.0015142950804850658
# supervised learning by regression:		0.001510130573598429
# latent dirichlet allocation:		0.001461798195478191
# bayesian network models:		0.0014035055408490084
# markov decision processes:		0.0013933553526592466
# markov decision processes:		0.0013932406611987236
# information visualization:		0.0013892872971955647
# perceptron algorithm:		0.0013351193275757355
# cognitive robotics:		0.0013213960114200113
# modelling:		0.0012944959032232851
# matching:		0.0012306720768091581
# 2d pca:		0.0012170879658035011
# 2d pca:		0.0012155868950598802
# contingency table analysis:		0.0011856605805355422
# generalized eigenvalue:		0.001175551391344384
# cloud computing:		0.001163882749877707
# visualization toolkits:		0.0011601007358965495
# collaborative search:		0.0011544777584274629
# unidimensional range search:		0.0011483011105713043
# generative adversarial networks gan:		0.0011405325260059737
# stream management:		0.001117938250885184
# structured prediction:		0.0011134187536166527
# video search:		0.0011088341164318958
# mapreduce-based systems:		0.001098119115328269
# deep web:		0.001089214815409095
# markov network models:		0.0010635160898436976
# deadlocks:		0.0010626953409299442
# record and block layout:		0.0010596346724811685
# decision diagrams:		0.0010048804930467164
# data compression:		0.0009894564671030196
# key-value stores:		0.0009767620906750772
# gaussian processes:		0.0009744166986557527
# gaussian processes:		0.0009716544970789483
# bayesian networks:		0.0009715881083227002
# ranking:		0.0009576324483935931
# bootstrapping:		0.0009545125096329583
# support vector machines:		0.0009470871659591573
# support vector machines:		0.0009434061091596814
# network data models:		0.0009319358078946472
# object identification:		0.0008732252771609942
# rank aggregation:		0.0008626355311887173
# bagging:		0.0008425242108321709
# cost-sensitive learning:		0.0008415328571101018
# query planning:		0.0007943406970668498
# survival analysis:		0.0007941773522284056
# semi-structured data:		0.0007918832912707237
# knowledge discovery:		0.0007498019002458067
# graph partitioning:		0.0007337107004658732
# query suggestion:		0.0007171692967674424
# simulated annealing:		0.0007126057610666687
# parallel implementation:		0.0007041392153519494
# xpath:		0.000649639426520816
# reconstruction:		0.0006478866344599897
# rule-based netwok archirtecture:		0.0006442703320378855
# call level interfaces:		0.0005812186515540346
# auto-encoder:		0.0005660809815245449
# main memory engines:		0.0005621056705328668
# jackknifing:		0.00055634773045412
# dictionaries:		0.0005360770376157158
# data integration:		0.000535692645133627
# renewal theory:		0.0005124017401375199
# quantile regression:		0.0004998136594506054
# mathematics retrieval:		0.0004965079854835825
# data mining tools:		0.0004771160118535187
# similarity measures:		0.0004620258089416279
# cross-validation:		0.00046069882201871536
# information extraction:		0.0004307882324037293
# markov networks:		0.0004301571252567985
# adversarial learning:		0.0004286299389235662
# adversarial learning:		0.0004279885405338802
# information extraction:		0.00042695458384148244
# uncertainty:		0.00041749018430611477
# transformer nn:		0.0004033721448398201
# taxonomy mapping:		0.0003706386995452653
# learning from demonstrations:		0.0003597116997905761
# graph embedding:		0.0003539173221418009
# semi-supervised learning:		0.0003379708342650713
# anomaly detection:		0.0003155474033771375
# anomaly detection:		0.0003132048195539942
# regret bounds:		0.00030706082782055446
# scalable:		0.00030630867325904995
# dynamic:		0.00029170003172207954
# theory of database privacy and security:		0.00028697538274381567
# phonology:		0.0002447808529029664
# geographic visualization:		0.00020855183935610826
# market graph:		0.00020024590652710785
# language resources:		0.00019724243466223078
# evolving nn:		0.00018625876806963577
# loopy belief propagation:		0.00014229848872361161
# distribution functions:		0.00011540153535673793
# data encryption:		0.00010440818259051588
# splitting criteria:		9.659872781468647e-05
# smart city:		5.888646482367036e-05
# ensembling:		4.507693615556696e-05
# dropout:		3.5793583001632194e-05
# data scans:		2.5711777123007362e-05
# learning from implicit feedback:		1.8751546880621518e-05

# %% [markdown]
# #### AI

# %%
contrib_AI = np.load('clusters/AI_contrib.npy')
print(f'Cluster contributions: {contrib_AI}')
# Out:
# Cluster contributions: [0.02048352 0.01977237 0.0055853  0.00547745 0.00286389]

# %%
print('AI, Cluster 1:')
terms_AI.sort(reverse=True, key=lambda x: x[1])
for el in terms_AI:
    if el[1] == 0:
        break
    print(f'{el[0]}:\t\t{el[1]}')
# Out:
# AI, Cluster 1:
# support vector machines:		0.3819018050052615
# anomaly detection:		0.35480000486855523
# distributed database recovery:		0.3428976977378799
# 2d pca:		0.326197441647439
# gaussian processes:		0.27492639083327725
# boosting:		0.26870030745010426
# markov decision processes:		0.25729433468901614
# cluster analysis:		0.2526371877594142
# bayesian network models:		0.24137518484187223
# apprenticeship learning:		0.17163801632548897
# markov networks:		0.1565495007637852
# recommender systems:		0.14674827846309288
# information extraction:		0.13031835919783943
# data locking:		0.12476473857591884
# learning to rank:		0.12182756680249088
# data cleaning:		0.11299497117537075
# adversarial learning:		0.09461650350790746
# sequential decision making:		0.0917504874887954
# data exchange:		0.09019242142565233
# multi-agent reinforcement learning:		0.05835104483678031
# data provenance:		0.05028247248097171
# inverse reinforcement learning:		0.03335358561056711
# inconsistent data:		2.428009045602563e-10
# probabilistic retrieval models:		1.6846532414340838e-10
# independent component analysis:		1.6500372084931193e-10
# structured query language:		1.6005806717699992e-10
# graph based conceptual clustering:		1.5022913489027052e-10
# mapreduce languages:		1.1970067812239456e-10
# hierarchical representations:		1.1635667451686269e-10
# data structures and algorithms for data management:		1.128121436940078e-10
# active learning settings:		1.0873599263896289e-10
# unsupervised learning and clustering:		1.042799809056654e-10
# factor analysis:		9.576592206935069e-11
# dimensionality reduction:		9.386210486909942e-11
# deep reinforcement learning drl:		8.944367476109656e-11
# clustering and classification:		8.778201438349624e-11
# fuzzy representation:		7.801855335216994e-11
# data modeling:		7.725676609383532e-11
# desktop search:		7.104117198692505e-11
# relational database model:		6.749456973653074e-11
# default reasoning and belief revision:		6.536549823775972e-11
# temporal difference learning:		6.393647000698962e-11
# xquery:		6.090601557302612e-11
# online learning theory:		6.00714527611367e-11
# presentation of retrieval results:		5.959556027128619e-11
# markov processes:		5.73434197688029e-11
# online analytical processing engines:		5.3826419244271544e-11
# reasoning about belief and knowledge:		5.170420290525215e-11
# semi-supervised learning:		5.1511825772582626e-11
# deduplication:		5.1383699962169216e-11
# mixture models:		5.0874710470761954e-11
# statistical relational learning:		4.9825478305520126e-11
# parallel computation:		4.97882639700735e-11
# inductive logic learning:		4.7556818820378274e-11
# spline models:		4.5759497384529085e-11
# query optimization:		4.5713769409405814e-11
# kernel approach:		4.0617975388424724e-11
# equational models:		3.9428541564612804e-11
# dictionaries:		3.770804274474738e-11
# object detection:		3.3640455500847816e-11
# question answering:		3.296288993164334e-11
# visualization toolkits:		3.0540795826769974e-11
# supervised learning by regression:		3.033121545451459e-11
# site wrapping:		2.997659837206819e-11
# formal concept analysis:		2.8293059480489222e-11
# lifelong machine learning:		2.7891232165760594e-11
# document collection models:		2.78185156998969e-11
# discourse dialogue and pragmatics:		2.6625196425161104e-11
# data streams:		2.6449580949624733e-11
# video segmentation:		2.4171174003728495e-11
# decision diagrams:		2.3916160271403465e-11
# semantic networks:		2.381009388700933e-11
# tensor representation:		2.345902217552472e-11
# information retrieval diversity:		2.2909535859085112e-11
# data encoding and canonicalization:		2.2273789088834187e-11
# time series analysis:		2.163605698327386e-11
# approximate dynamic programming methods:		2.092785162592442e-11
# batch learning:		2.0631486051108306e-11
# bayesian nonparametric models:		2.0339865276631266e-11
# entity resolution:		1.998711720326799e-11
# additive clustering:		1.869170850388651e-11
# metropolis-hastings algorithm:		1.8593170724820594e-11
# policy iteration:		1.8268575927601147e-11
# renewal theory:		1.820908941092183e-11
# dendrograms:		1.8022642020254667e-11
# variable elimination:		1.7437477161515717e-11
# web log analysis:		1.7376379098802442e-11
# federated databases:		1.701051440887961e-11
# image search:		1.623626622345306e-11
# survival analysis:		1.62130582176405e-11
# join algorithms:		1.6209805529772533e-11
# logic and databases:		1.6117236037180078e-11
# non-negative matrix factorization:		1.6001447593611566e-11
# frequent graph mining:		1.594123660276777e-11
# speech recognition:		1.5610321753550383e-11
# kernel matrix:		1.5194789974779167e-11
# feature selection:		1.483853873588921e-11
# query intent:		1.4507103426975898e-11
# scientific visualization:		1.4367668080275845e-11
# stochastic games:		1.3934652131174265e-11
# data integration:		1.3827942071620774e-11
# transfer learning:		1.3642270619732873e-11
# query planning:		1.3396022145307247e-11
# text categorization:		1.3077338680095043e-11
# semantic inference:		1.2721478820541192e-11
# maximum a posteriori modeling:		1.2307857131660302e-11
# rule-based netwok archirtecture:		1.193236051511988e-11
# q-learning:		1.1238345920646698e-11
# natural language generation:		1.1167907616378427e-11
# cross-validation:		1.1089109141876324e-11
# fusion of classifiers:		1.094974440622733e-11
# graph embedding:		1.048575200135076e-11
# spatial and physical reasoning:		1.0473812167620374e-11
# web and social media search:		1.0270204441916027e-11
# hadoop:		1.0184022431003842e-11
# learning under covariate shift:		1.013550592681391e-11
# causal reasoning and diagnostics:		9.867447882688077e-12
# process mining:		9.72863028965321e-12
# sparse tensor:		9.727916007532525e-12
# traffic analysis:		9.193715823287006e-12
# recurrent neural networks rnn:		9.152339956431352e-12
# expert search:		8.914076852864453e-12
# learning from demonstrations:		8.716103452199339e-12
# multidimensional range search:		8.41841751678812e-12
# document topic models:		8.411132524242358e-12
# query operators:		8.35511951741192e-12
# mapreduce-based systems:		8.282474803967633e-12
# transformer nn:		7.696106216775298e-12
# enterprise search:		7.517822111475866e-12
# database constraints theory:		7.298962344096223e-12
# bagging:		6.8145252938283975e-12
# ranking:		6.762458972225218e-12
# tracking:		6.557142647130457e-12
# markov-chain monte carlo convergence measures:		6.324979790153263e-12
# market graph:		6.1683951127767915e-12
# nonlinear principal components:		5.999454452842367e-12
# scalable:		5.765779457364769e-12
# quality of the data:		5.75307874911359e-12
# key-value stores:		5.585348717779004e-12
# query reformulation:		5.5828521836696665e-12
# generalized eigenvalue:		5.283368101624392e-12
# temporal data:		5.080931077223072e-12
# latent dirichlet allocation:		4.846184948219798e-12
# key-phrase indexing:		4.729771625046094e-12
# maximum likelihood estimation:		4.717799548571677e-12
# retrieval effectiveness:		4.459529612535878e-12
# nearest-neighbor search:		4.393375308568074e-12
# deep web:		4.2731832520287316e-12
# database interoperability:		4.086368079715801e-12
# empirical studies in visualization:		4.000899949768118e-12
# data mining tools:		3.778337850791979e-12
# shape inference:		3.681788030609671e-12
# robust regression:		3.574319092937927e-12
# ensembling:		3.552526194109427e-12
# heat maps:		3.5373429872046412e-12
# cost-sensitive learning:		3.367874596268407e-12
# smart home:		3.3230441469435494e-12
# boolean function learning:		3.1838263269953528e-12
# thesauri:		3.1742304231063e-12
# knowledge sharing:		3.0079911905456995e-12
# cloud computing:		2.992861999140701e-12
# partially-observable markov decision processes:		2.9394666424641797e-12
# multivariate statistics:		2.841043546867901e-12
# perceptron algorithm:		2.8407277393472054e-12
# kernel-based clustering:		2.509119304517477e-12
# deadlocks:		2.4154824137325467e-12
# phonology:		2.3832509712786095e-12
# treemaps:		2.3483128013766266e-12
# jackknifing:		2.3281361346516516e-12
# transaction logging:		2.1824541412484193e-12
# distribution functions:		2.062610066708888e-12
# summarization:		1.871505313308883e-12
# incomplete data:		1.799144910503669e-12
# search interfaces:		1.7763110138245796e-12
# relevance assessment:		1.7251248692147154e-12
# integrity checking:		1.5399889753329992e-12
# chemical and biochemical retrieval:		1.5306712244830693e-12
# wrappers:		1.4365732243368985e-12
# critical nodes detection:		1.418351883110721e-12
# triggers and rules:		1.3587566299803069e-12
# loopy belief propagation:		1.3050909639387736e-12
# learning from critiques:		1.2317415964915315e-12
# document filtering:		1.1283861837056864e-12
# evolving nn:		1.122563462353158e-12
# rule and pattern discovery:		1.1097583881883855e-12
# source separation:		1.0717705750700809e-12
# matching:		9.490997675745274e-13
# call level interfaces:		8.825529308325648e-13
# point lookups:		4.5268610913669256e-13
# gibbs sampling:		3.5213748335533406e-13
# hyperbolic trees:		2.905684688658722e-13
# bayesian computation:		1.7488167408787708e-13
# cognitive robotics:		1.7022980971495436e-13
# multi-agent learning:		9.191183493104807e-14
# least moduli:		6.308620752944792e-14

# %%
print('AI, Cluster 2:')
terms_AI.sort(reverse=True, key=lambda x: x[2])
for el in terms_AI:
    if el[2] == 0:
        break
    print(f'{el[0]}:\t\t{el[2]}')
# Out:
# AI, Cluster 2:
# support vector machines:		0.4097246523865225
# 2d pca:		0.34313786294874077
# anomaly detection:		0.3420705733991426
# gaussian processes:		0.27984167662897663
# distributed data locking:		0.2755050924666692
# boosting:		0.26740165675834565
# markov decision processes:		0.25369554511481973
# cluster analysis:		0.236124752887918
# markov network models:		0.2244326824453322
# database recovery:		0.21509584815670188
# bayesian networks:		0.1851059051914503
# apprenticeship learning:		0.15936089161891304
# recommender systems:		0.14526914399850377
# information extraction:		0.12886503095103707
# learning to rank:		0.11825584537426756
# data cleaning:		0.1143902958207284
# adversarial learning:		0.09121618218204301
# data exchange:		0.08954881371387764
# sequential decision making:		0.08139716720414208
# data provenance:		0.06151437796089847
# multi-agent reinforcement learning:		0.04813867495370546
# inverse reinforcement learning:		0.03733584259163887

# %%
print('AI, Cluster 3:')
terms_AI.sort(reverse=True, key=lambda x: x[3])
for el in terms_AI:
    if el[3] == 0:
        break
    print(f'{el[0]}:\t\t{el[3]}')
# Out:
# AI, Cluster 3:
# support vector machines:		0.467073855287433
# cluster analysis:		0.42633169593482256
# anomaly detection:		0.38263054438290045
# apprenticeship learning:		0.3035107462080092
# data provenance:		0.25017700624479583
# 2d pca:		0.24893826470473518
# distributed database recovery:		0.2389726853396938
# sequential decision making:		0.2305779247640998
# multi-agent reinforcement learning:		0.2050782724160649
# markov decision processes:		0.16010643555240034
# inverse reinforcement learning:		0.10375659113238551
# boosting:		0.10301467661479788
# learning to rank:		0.10221596415369721
# data locking:		0.08693069392538968
# bayesian network models:		0.0846975436514543
# adversarial learning:		0.06514882724722768
# markov networks:		0.054920410755000225
# recommender systems:		0.053040476032016746
# information extraction:		0.029322720497506245
# gaussian processes:		0.02858323065359169
# data exchange:		0.02563977377424034
# data cleaning:		0.008366298954496835

# %%
print('AI, Cluster 4:')
terms_AI.sort(reverse=True, key=lambda x: x[4])
for el in terms_AI:
    if el[4] == 0:
        break
    print(f'{el[0]}:\t\t{el[4]}')
# Out:
# AI, Cluster 4:
# support vector machines:		0.4684796728498491
# cluster analysis:		0.44121959117922027
# anomaly detection:		0.3802025495308368
# apprenticeship learning:		0.31479379045164757
# data provenance:		0.2693193600689445
# sequential decision making:		0.24376337047301355
# 2d pca:		0.2346307776315456
# multi-agent reinforcement learning:		0.21953744136277295
# distributed data locking:		0.16965400300612637
# markov decision processes:		0.14557678366360427
# database recovery:		0.13255615429656314
# inverse reinforcement learning:		0.1098390911904022
# learning to rank:		0.09785642703149249
# boosting:		0.08077603625554645
# adversarial learning:		0.06002314167790333
# markov network models:		0.057330509891136874
# bayesian networks:		0.04725557762851908
# recommender systems:		0.040380823879650356
# data exchange:		0.016948052271871076
# information extraction:		0.015785433031568433

# %%
print('AI, Cluster 5:')
terms_AI.sort(reverse=True, key=lambda x: x[5])
for el in terms_AI:
    if el[5] == 0:
        break
    print(f'{el[0]}:\t\t{el[5]}')
# Out:
# AI, Cluster 5:
# learning to rank:		0.44415922476065994
# information extraction:		0.4226382878998822
# markov decision processes:		0.3395194849457521
# data cleaning:		0.3063693800407274
# data provenance:		0.267561113900364
# recommender systems:		0.2583785315554916
# boosting:		0.2485458993362883
# 2d pca:		0.23175675960452188
# sequential decision making:		0.18900259067647765
# adversarial learning:		0.18560273865739266
# data exchange:		0.1601073546022096
# apprenticeship learning:		0.12527786273345767
# support vector machines:		0.1216555585320845
# anomaly detection:		0.10568865269111494
# cluster analysis:		0.09891908835740307
# inverse reinforcement learning:		0.07839098120327641
# gaussian processes:		0.05031403288789675
# multi-agent reinforcement learning:		0.0436258966021172
# distributed data locking:		0.043213988352151414
# database recovery:		0.03379741917409715
# markov network models:		0.0130211208083743
# bayesian networks:		0.010749948130869429

# %% [markdown]
# #### Machine Learning (Statistics)

# %%
contrib_ML = np.load('clusters/ML_contrib.npy')
print(f'Cluster contributions: {contrib_ML}')
# Out:
# Cluster contributions: [0.01943845 0.01867466 0.00483639]

# %%
print('Machine Learning (Statistics), Cluster 1:')
terms_ML.sort(reverse=True, key=lambda x: x[1])
for el in terms_ML:
    if el[1] == 0:
        break
    print(f'{el[0]}:\t\t{el[1]}')
# Out:
# Machine Learning (Statistics), Cluster 1:
# adversarial learning:		0.3736923549301199
# learning to rank:		0.3685328483004863
# distributed database recovery:		0.3527455968860433
# boosting:		0.3469433442790289
# multi-agent reinforcement learning:		0.3064425099811277
# bayesian network models:		0.3027894284894846
# support vector machines:		0.28473314716948805
# data cleaning:		0.1949433135574657
# markov networks:		0.19021091936548537
# data exchange:		0.14816048088094896
# sequential decision making:		0.13707836249628666
# recommender systems:		0.13492380986079155
# markov decision processes:		0.13441304175391872
# apprenticeship learning:		0.1276275507342564
# data locking:		0.11943487621544069
# gaussian processes:		0.11792717160453721
# data provenance:		0.09803808666851291
# cluster analysis:		0.07524444295746532
# information extraction:		0.03250740709333087
# inverse reinforcement learning:		0.02919529880692395
# anomaly detection:		0.015234436604552813
# 2d pca:		0.002436450163272978
# fuzzy representation:		5.374078813483538e-10
# video segmentation:		2.5354187854608023e-10
# hierarchical representations:		1.9784547854335282e-10
# relational parallel and distributed dbmss:		1.761340323985823e-10
# mixture models:		1.6750665742115736e-10
# document collection models:		1.63048035629577e-10
# topic modeling:		1.535086658819388e-10
# image search:		1.2081128975589009e-10
# query learning:		1.1642740561938584e-10
# xquery:		1.1401995943783703e-10
# database query languages:		7.88235529899235e-11
# language models:		7.646954183163963e-11
# statistical graphics:		7.302799730946378e-11
# biclustering:		6.479182327718608e-11
# probabilistic retrieval models:		6.4214368956014e-11
# document structure:		6.087358446540988e-11
# active learning settings:		6.073821174691037e-11
# bayesian computation:		5.369994567696366e-11
# visualization toolkits:		5.1612746368561035e-11
# inconsistent data:		4.615049605921677e-11
# kernel approach:		4.414377191582942e-11
# temporal reasoning:		4.40644030665308e-11
# online analytical processing engines:		4.15038076015271e-11
# query optimization:		4.100923390053692e-11
# semantic inference:		3.716516756731201e-11
# deep belief networks:		3.686507661781855e-11
# graph based conceptual clustering:		3.416812973894367e-11
# online learning theory:		3.411661533829413e-11
# knowledge discovery:		3.2116801017883014e-11
# search results deduplication:		3.153927598633808e-11
# query log analysis:		3.094408725122626e-11
# unsupervised learning and clustering:		3.075527988241877e-11
# inductive logic learning:		2.975251759426162e-11
# document filtering:		2.8835468146045954e-11
# mapreduce:		2.8677998132227764e-11
# data modeling:		2.858209143458615e-11
# semi-structured data:		2.5913937856852443e-11
# data stream mining:		2.5717548533178094e-11
# record and buffer management:		2.4712726575164272e-11
# unidimensional range search:		2.4692460103612885e-11
# object recognition:		2.4658958009583677e-11
# information visualization:		2.332516276331404e-11
# structured text search:		2.2588603576642318e-11
# maximum likelihood estimation:		2.055807292714904e-11
# mediators and data integration:		2.055576234209948e-11
# non-negative matrix factorization:		1.8834183377137816e-11
# stochastic differential equations:		1.8258872694514793e-11
# batch learning:		1.8099760282537934e-11
# discourse dialogue and pragmatics:		1.800631373161143e-11
# near-duplicate and plagiarism detection:		1.7835168526712724e-11
# dendrograms:		1.6564955809678466e-11
# join algorithms:		1.5399381643857754e-11
# independent component analysis:		1.495762418258945e-11
# factor graphs:		1.4468093926564123e-11
# factorial hmm:		1.419646734595141e-11
# site wrapping:		1.4056396473358466e-11
# network data models:		1.3644551146138037e-11
# interest point and salient region detections:		1.356381370372533e-11
# critical nodes detection:		1.3332117933103326e-11
# key-phrase indexing:		1.2980636915700745e-11
# time series analysis:		1.2196088694096439e-11
# multiresolution:		1.187382372191612e-11
# renewal theory:		1.1720343073108922e-11
# knowledge sharing:		1.1278365099925841e-11
# traffic analysis:		1.0895063048225312e-11
# question answering:		1.0864517666466811e-11
# boolean function learning:		1.0516017526543429e-11
# thesauri:		1.029583621414843e-11
# visualization design and evaluation methods:		1.0063018664704461e-11
# approximate dynamic programming methods:		9.990162649051873e-12
# massive data clustering:		9.592667735246269e-12
# database views:		9.190729983687067e-12
# schema matching:		9.122702039102403e-12
# speech:		8.429695239590394e-12
# music retrieval:		8.413668854877713e-12
# dimensionality reduction:		8.15521785634914e-12
# hypothesis testing and confidence interval computation:		7.983680995532422e-12
# variable elimination:		7.607040973924238e-12
# heat maps:		7.55474558068766e-12
# recurrent neural networks rnn:		7.532908850540462e-12
# integrity checking:		7.263714286037141e-12
# max marginal computation:		7.230699163087109e-12
# extraction transformation and loading:		6.663018473607441e-12
# generative adversarial networks gan:		6.50702743354021e-12
# rule-based netwok archirtecture:		6.374070145709559e-12
# consensus clustering:		5.777157640238584e-12
# mapreduce-based systems:		5.764512015251007e-12
# dbms engine architectures:		5.611567407074442e-12
# triggers and rules:		5.573136181620875e-12
# data encryption:		5.569877404587988e-12
# data compression:		5.398341031279265e-12
# key-value stores:		5.354837130082717e-12
# scientific visualization:		5.30631135762649e-12
# multivariate statistics:		5.252620683671403e-12
# markov-chain monte carlo convergence measures:		5.076119734943138e-12
# exploratory data analysis:		4.941768829238875e-12
# hadoop:		4.820637578153702e-12
# machine translation:		4.754698012875091e-12
# call level interfaces:		4.5403717124512825e-12
# modelling:		4.166580570569345e-12
# feature selection:		4.1122432344694805e-12
# frequent graph mining:		4.023703267408684e-12
# nonparametric statistics:		4.017818665269469e-12
# retrieval effectiveness:		3.967127914718517e-12
# latent dirichlet allocation:		3.957366980921095e-12
# metropolis-hastings algorithm:		3.7367087707141e-12
# causal reasoning and diagnostics:		3.714022424165376e-12
# nearest-neighbor search:		3.65539522945327e-12
# quality of the data:		3.6072774755708807e-12
# types of association rules:		3.564423277996382e-12
# regret bounds:		3.3250822648791527e-12
# entity relationship models:		3.3211590194409745e-12
# smart home:		3.2972554422869134e-12
# structured outputs:		3.118485633733841e-12
# policy iteration:		3.066717468256544e-12
# query intent:		2.956840010885363e-12
# trajectory clustering:		2.9146341114479305e-12
# instance-based learning:		2.908037973184398e-12
# cross-validation:		2.8780113298081724e-12
# quantile regression:		2.6459150475122047e-12
# self organized map:		2.629694920091686e-12
# learning from demonstrations:		2.477149710700882e-12
# cloud computing:		2.472387966609944e-12
# fusion of classifiers:		2.4058294263287636e-12
# language resources:		2.291780477745126e-12
# reconstruction:		2.2768947014217897e-12
# federated databases:		2.1653839655585303e-12
# kernel-based clustering:		2.1016064423072336e-12
# maximum a posteriori modeling:		1.9492575748141525e-12
# least moduli:		1.9197254077263994e-12
# supervised learning by classification:		1.9001349014872638e-12
# business intelligence:		1.857337065399728e-12
# personalization:		1.8184771716291858e-12
# structured prediction:		1.8013210138852658e-12
# ontologies:		1.6356128269600601e-12
# smart city:		1.6029552882822295e-12
# shape inference:		1.406276683299009e-12
# surfacing:		1.4017781717866948e-12
# gibbs sampling:		1.3807563218527657e-12
# q-learning:		1.3807142636526046e-12
# cost-sensitive learning:		1.3520654640497672e-12
# summarization:		1.3441248916531698e-12
# empirical studies in visualization:		1.2953928001007654e-12
# query operators:		1.2478346282532929e-12
# spatial and physical reasoning:		1.1885125151473271e-12
# cognitive robotics:		1.0855168738261324e-12
# sparse tensor:		9.840966472991468e-13
# feature weight clustering:		9.103864039369581e-13
# scalable:		8.270331103614714e-13
# ranking:		6.297487874561221e-13
# wrappers:		5.988229286887695e-13
# robust regression:		5.217791620318669e-13
# ensembling:		4.98072951850991e-13
# expert search:		4.973553549565187e-13
# evolutionary approach:		4.942980769016384e-13
# click through data:		4.778191101634294e-13
# auto-encoder:		4.3681599141455536e-13
# dropout:		3.491259587303577e-13
# uncertainty:		3.0186161123161563e-13
# learning from implicit feedback:		2.675318073906174e-13
# query reformulation:		1.579308842372681e-13
# validation of data:		4.6235760553106795e-14

# %%
print('Machine Learning (Statistics), Cluster 2:')
terms_ML.sort(reverse=True, key=lambda x: x[2])
for el in terms_ML:
    if el[2] == 0:
        break
    print(f'{el[0]}:\t\t{el[2]}')
# Out:
# Machine Learning (Statistics), Cluster 2:
# adversarial learning:		0.37946689111894366
# learning to rank:		0.37509053164650547
# boosting:		0.3526648123941726
# multi-agent reinforcement learning:		0.31009805055848577
# support vector machines:		0.2899971081974449
# distributed data locking:		0.27854805037219893
# markov network models:		0.26706665540265795
# bayesian networks:		0.23314226913140526
# database recovery:		0.20352167259633477
# data cleaning:		0.1976597840373411
# data exchange:		0.14995875920557247
# sequential decision making:		0.1388511217453459
# recommender systems:		0.13612519935719503
# markov decision processes:		0.13590285676820169
# apprenticeship learning:		0.12878592908564462
# gaussian processes:		0.11897898622660151
# data provenance:		0.09841994630344361
# cluster analysis:		0.0758032826760344
# information extraction:		0.03104780596555398
# inverse reinforcement learning:		0.028446852603110584
# anomaly detection:		0.01431916015369153
# 2d pca:		0.0011823843825989517

# %%
print('Machine Learning (Statistics), Cluster 3:')
terms_ML.sort(reverse=True, key=lambda x: x[3])
for el in terms_ML:
    if el[3] == 0:
        break
    print(f'{el[0]}:\t\t{el[3]}')
# Out:
# Machine Learning (Statistics), Cluster 3:
# data provenance:		0.49455791368616586
# apprenticeship learning:		0.3928307404541719
# sequential decision making:		0.33246769677579496
# bayesian network models:		0.2827993911906054
# multi-agent reinforcement learning:		0.24760203499107813
# gaussian processes:		0.24455092106236578
# adversarial learning:		0.2124162795962565
# inverse reinforcement learning:		0.20807031598371856
# cluster analysis:		0.19438661526075787
# markov networks:		0.17765378251039915
# data cleaning:		0.17685954526258704
# 2d pca:		0.1701004182528179
# markov decision processes:		0.1511645008204334
# information extraction:		0.13423831610767478
# support vector machines:		0.0887637617092758
# boosting:		0.08716866304026843
# distributed data locking:		0.06502219174845411
# learning to rank:		0.06404264874232415
# anomaly detection:		0.05481575333800362
# database recovery:		0.04760784367223929
# data exchange:		0.03731493000949169
# recommender systems:		0.012603563454247952
# information visualization:		2.2150470305076596e-06
# distribution functions:		2.195533068308961e-06
# expectation maximization:		2.1939710108257052e-06
# statistical relational learning:		2.164897603779102e-06
# reconstruction:		2.138293951475785e-06
# object identification:		2.1382925364506516e-06
# active learning:		2.123746029644805e-06
# personalization:		2.1234961631977003e-06
# equational models:		2.1213715202597847e-06
# variational methods:		2.105510907334607e-06
# query representation:		2.1020978393055346e-06
# learning from demonstrations:		2.098899621583409e-06
# query optimization:		2.0959449245387486e-06
# shape representations:		2.0899249115468063e-06
# tensor representation:		2.0761717757887773e-06
# data integration:		2.071915877310331e-06
# deduplication:		2.065319843347005e-06
# dimensionality reduction:		2.0616378325289203e-06
# parallel implementation:		2.0408434253510806e-06
# probabilistic algorithms:		2.039680993517523e-06
# feature selection:		2.033159615039797e-06
# video segmentation:		2.0265549896802258e-06
# parallel computation:		2.0228431050861156e-06
# bayesian computation:		2.019530377154525e-06
# structured prediction:		2.0132114432143054e-06
# summarization:		2.0014069378592256e-06
# image segmentation:		1.9913031961999375e-06
# query reformulation:		1.9899243650899324e-06
# active learning settings:		1.9892200223866417e-06
# fuzzy representation:		1.98623343780733e-06
# value iteration:		1.9823313195135318e-06
# supervised learning by classification:		1.9807066081019177e-06
# variable elimination:		1.979609883420717e-06
# relational database model:		1.979225990547454e-06
# hierarchical representations:		1.9769290409906524e-06
# extraction transformation and loading:		1.9724295582723425e-06
# sample complexity and generalization bounds:		1.970471427358327e-06
# random number generation:		1.9692245528551033e-06
# clustering and classification:		1.966031984569592e-06
# visualization design and evaluation methods:		1.9588477098535474e-06
# boolean function learning:		1.9570240856719856e-06
# stochastic differential equations:		1.9535487254821486e-06
# scientific visualization:		1.9404802901146287e-06
# inductive inference:		1.9393562641081866e-06
# text categorization:		1.9380680087597366e-06
